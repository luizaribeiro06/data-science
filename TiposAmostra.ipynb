# %% [markdown]
# <a href="https://colab.research.google.com/github/luizaribeiro06/data-science/blob/main/TiposAmostra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#amostragem

#passo 1 - vamos criar o bd (a população da amostra)

# %%
import pandas as pd
import numpy as np

#criando um dataframe fictício
np.random.seed(42) # garante a reprodução do experimento, varia a escolha dos números de 42 em 42 vezes,
n = 10000 # qtd de clientes que queremos gerar os dados - numero de linhas

#matriz com comandos que gera de forma aleatoria
#nome dataframe - df (exemplo)


df = pd.DataFrame({
    "ID": range(1, n+1), # dentro de um intervalo de 1 a n+1, lembrando q não é índice pois o índice começa no 0 as always
    "Idade": np.random.randint(18, 65, n), #randint - numeros inteiros de forma aleatoria
    "Renda": np.random.randint(2000, 3000, n), #(menor, maior e qts vezes (a variavel de qtd))
    "Regiao": np.random.choice(["Norte", "Sul", "Leste", "Oeste"], n) #choice: pode escolher opções
})

# %%
#amostra de 5 linhas da tabela criada
df.sample(5)
# Out:
#         ID  Idade  Renda Regiao
# 4753  4754     46   2594  Oeste
# 1705  1706     45   2103  Leste
# 9417  9418     28   2805  Norte
# 4042  4043     64   2199  Leste
# 8883  8884     42   2160  Norte

# %%
#amostragem aleatória simples (sem critério nenhum)
#criando uma tabela que puxa os dados do dataframe(escolhe qtd de linhas e escolhe a variação)
amostra_simples = df.sample(n=1000, random_state=42) #random_stade tem a mesma função do seed
amostra_simples.head() #só o começo da tabela
# Out:
#         ID  Idade  Renda Regiao
# 6252  6253     52   2647  Leste
# 4684  4685     40   2544  Leste
# 1731  1732     52   2217  Oeste
# 4742  4743     20   2278  Leste
# 4521  4522     18   2401  Norte

# %%
#amostragem aleatória sistemática (pega as linhas com base na variação)
#garante que não tenha nenhuma escolha preferida ex:verificação natura
intervalo = np.random.randint(1, 50) #inicio e intervalo
#cria-se a tabela baseada nesse intervalo
amostra_sistematica = df.iloc[::intervalo, :]#sempre que tiver intervalo será assim
amostra_sistematica.head()
# Out:
#     ID  Idade  Renda Regiao
# 0    1     56   2526  Norte
# 17  18     19   2849  Oeste
# 34  35     64   2845    Sul
# 51  52     64   2152  Norte
# 68  69     43   2524  Norte

# %%
#amostragem estratificada (separa de acordo com o parâmetro escolhido)
#split - separação
from sklearn.model_selection import train_test_split
#cria-se a tabela, criando uma estratififação, tendo o dataframe, testando a amostra de 0.5 e estratifica por regiao
#ele vai pegar uma amostragem equivalente de acordo com as regioes, ele vai pegar 0.5 de forma proporcional em cada regiao
amostra_estratificada, _ = train_test_split(df, test_size=0.5, stratify=df["Regiao"])
amostra_estratificada.head()
# Out:
#         ID  Idade  Renda Regiao
# 1543  1544     35   2168  Oeste
# 6005  6006     33   2953  Leste
# 2671  2672     21   2924  Oeste
# 4456  4457     37   2364    Sul
# 1060  1061     34   2824    Sul

# %%
#amostragem por conglomerado - cluster
#pega TODOS daquele parametro
clusters = df.groupby('Regiao') #vai ser um agrupamento por região
amostra_conglomerados = clusters.get_group('Sul')
amostra_conglomerados.head()
# Out:
#    ID  Idade  Renda Regiao
# 2   3     32   2939    Sul
# 3   4     60   2519    Sul
# 6   7     56   2324    Sul
# 7   8     36   2113    Sul
# 8   9     40   2146    Sul

# %%
#amostragem por conveniência - só pega o que escolher e for conveniente
#ex: perfil no instagram - premio para os primeiros 1000 seguidores
#sempre por ordenação
amostra_conveniencia = df.head(1000)
amostra_conveniencia.head()
# Out:
#    ID  Idade  Renda Regiao
# 0   1     56   2526  Norte
# 1   2     46   2052  Oeste
# 2   3     32   2939    Sul
# 3   4     60   2519    Sul
# 4   5     25   2329  Norte

# %%
#amostragem por julgamento - parâmetros específicos
amostra_julgamento = df[(df['Idade'] > 30) &
                        (df['Idade'] <=55) &
                        (df['Renda'] > 1500) |
                        (df['Renda'] != 'Oeste')].sample(n=1000, random_state=42)
amostra_julgamento.head()
# Out:
#         ID  Idade  Renda Regiao
# 6252  6253     52   2647  Leste
# 4684  4685     40   2544  Leste
# 1731  1732     52   2217  Oeste
# 4742  4743     20   2278  Leste
# 4521  4522     18   2401  Norte

# %%
#amostragem por cotas
#sorteio estratificado por regiao, pega x registros de cada região do df, embaralhados aleatoriamente e guardando em uma amsotra
#para usar o comando lambda, é preciso indexar se é verdadeiro ou falso

amostra_cotas = df.groupby('Regiao').apply(lambda x: x.sample(n=25)).reset_index(drop=True)
amostra_cotas.head()
# Out:
# /tmp/ipython-input-3552157455.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   amostra_cotas = df.groupby('Regiao').apply(lambda x: x.sample(n=25)).reset_index(drop=True)
#      ID  Idade  Renda Regiao
# 0  7818     41   2993  Leste
# 1   578     22   2527  Leste
# 2  3542     59   2100  Leste
# 3  5038     22   2722  Leste
# 4  6589     35   2064  Leste

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
n = 5000

dfCP = pd.DataFrame({
    'ID_Transacao': range(1, n+1),
    'Valor': np.random.uniform(10, 10000, n),
    'Tipo_Transacao': np.random.choice(['Compra', 'Transferencia', 'Pagamento'], n),
    'Localizacao': np.random.choice(['SP', 'RJ', 'MG', 'RS', 'BA', 'PR'], n),
    'Horario': np.random.choice(['Manha', 'Tarde', 'Noite', 'Madrugada'], n),
    'Fraude': np.random.choice([0, 1], n, p=[0.7, 0.3]) #% do 0 de 70% e do 1 30%
})
dfCP.head()

#1. Realizar uma amostragem aleatÃ³ria simples com 500 registros.
amostra_simples = dfCP.sample(n=500, random_state=42)
amostra_simples.head()
# Out:
#       ID_Transacao        Valor Tipo_Transacao Localizacao    Horario  Fraude
# 1501          1502  4797.026958      Pagamento          SP      Manha       0
# 2586          2587   727.040304         Compra          BA  Madrugada       0
# 2653          2654   533.026652  Transferencia          RJ      Noite       0
# 1055          1056  3513.611036      Pagamento          SP      Manha       0
# 705            706  9899.702722         Compra          BA  Madrugada       1

# %%
#2. Criar uma amostragem sistemÃ¡tica escolhendo cada 10Âº registro.
amostra_sistematica = dfCP.iloc[::10, :]
amostra_sistematica.head()
# Out:
#     ID_Transacao        Valor Tipo_Transacao Localizacao    Horario  Fraude
# 0              1  3751.655787      Pagamento          RS      Manha       0
# 10            11   215.639098         Compra          RJ      Tarde       0
# 20            21  6122.410418      Pagamento          MG      Manha       0
# 30            31  6079.373070  Transferencia          RJ      Manha       0
# 40            41  1229.161966      Pagamento          RS  Madrugada       0

# %%
#3. Dividir a base em estratos por localizaÃ§Ã£o e selecionar amostras proporcionais.
from sklearn.model_selection import train_test_split
amostra_estratificada, _ = train_test_split(dfCP, test_size=0.5, stratify=dfCP["Localizacao"])
amostra_estratificada.head()
# Out:
#       ID_Transacao        Valor Tipo_Transacao Localizacao    Horario  Fraude
# 1898          1899  3560.291841      Pagamento          RJ      Noite       0
# 3187          3188  3544.353696      Pagamento          RS      Tarde       0
# 1979          1980  8420.916332         Compra          SP      Noite       0
# 1479          1480  4361.477315      Pagamento          BA      Noite       0
# 4106          4107  9653.374209      Pagamento          SP  Madrugada       0

# %%
#4. Selecionar aleatoriamente transaÃ§Ãµes fraudulentas e comparar com transaÃ§Ãµes nÃ£o fraudulentas.
#pegou os que não são fraudulentos
clusters = dfCP.groupby('Fraude')

amostra_nao_fraudulentas = clusters.get_group(0)
amostra_fraudulentas = clusters.get_group(1)

amostra_nao_fraudulentas.head()
amostra_fraudulentas.head()
# Out:
#     ID_Transacao        Valor Tipo_Transacao Localizacao Horario  Fraude
# 1              2  9507.635921      Pagamento          RS   Tarde       1
# 4              5  1568.626218      Pagamento          BA   Manha       1
# 5              6  1568.385258         Compra          PR   Noite       1
# 6              7   590.255286      Pagamento          RJ   Manha       1
# 13            14  2131.267716      Pagamento          PR   Tarde       1

# %%
#5. Criar um subconjunto de dados com base em amostragem por julgamento para transaÃ§Ãµes acima de R$5000.
amostra_julgamento = dfCP[(dfCP['Valor'] > 5000)]
amostra_julgamento.head()
# Out:
#    ID_Transacao        Valor Tipo_Transacao Localizacao Horario  Fraude
# 1             2  9507.635921      Pagamento          RS   Tarde       1
# 2             3  7322.619479      Pagamento          RJ   Manha       0
# 3             4  5990.598257  Transferencia          MG   Manha       0
# 7             8  8663.099696         Compra          RJ   Manha       0
# 8             9  6015.138967      Pagamento          SP   Manha       0

# %%
#6. Aplicar amostragem por conglomerados dividindo os dados por tipo de transaÃ§Ã£o e sorteando um grupo.
import random
clusters = dfCP['Tipo_Transacao'].unique()

sorteio = random.choice(clusters)
grupos = dfCP.groupby('Tipo_Transacao')
amostra_conglomerados = grupos.get_group(sorteio)

amostra_conglomerados.head()
# Out:
#    ID_Transacao        Valor Tipo_Transacao Localizacao Horario  Fraude
# 0             1  3751.655787      Pagamento          RS   Manha       0
# 1             2  9507.635921      Pagamento          RS   Tarde       1
# 2             3  7322.619479      Pagamento          RJ   Manha       0
# 4             5  1568.626218      Pagamento          BA   Manha       1
# 6             7   590.255286      Pagamento          RJ   Manha       1

# %%
#7. Executar uma amostragem por conveniÃªncia pegando os 300 primeiros registros.
amostra_conveniencia = dfCP.head(300)
amostra_conveniencia.head()
# Out:
#    ID_Transacao        Valor Tipo_Transacao Localizacao Horario  Fraude
# 0             1  3751.655787      Pagamento          RS   Manha       0
# 1             2  9507.635921      Pagamento          RS   Tarde       1
# 2             3  7322.619479      Pagamento          RJ   Manha       0
# 3             4  5990.598257  Transferencia          MG   Manha       0
# 4             5  1568.626218      Pagamento          BA   Manha       1

# %%
#8. Criar uma amostragem por cotas considerando o tipo de transaÃ§Ã£o e localizaÃ§Ã£o.
amostra_cotasTransacao = dfCP.groupby('Tipo_Transacao').apply(lambda x: x.sample(n=25)).reset_index(drop=True)
print("Tamanho da amostra por cotas (Tipo de Transação):", len(amostra_cotasTransacao))
amostra_cotasTransacao.head()

amostra_cotasLocalizacao = dfCP.groupby('Localizacao').apply(lambda x: x.sample(n=25)).reset_index(drop=True)
print("\nTamanho da amostra por cotas (Localização):", len(amostra_cotasLocalizacao))
amostra_cotasLocalizacao.head()
# Out:
# Tamanho da amostra por cotas (Tipo de Transação): 75
#
# Tamanho da amostra por cotas (Localização): 150
# /tmp/ipython-input-2023352842.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   amostra_cotasTransacao = dfCP.groupby('Tipo_Transacao').apply(lambda x: x.sample(n=25)).reset_index(drop=True)
# /tmp/ipython-input-2023352842.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %%
print("Tamanho da Amostra Aleatória Simples:", len(amostra_simples))
print("Tamanho da Amostra Estratificada:", len(amostra_estratificada))

print("\nConclusão:")
print("Na amostragem simples, os registros são escolhidos de forma totalmente aleatória.")
print("Na estratificada, a escolha é proporcional às localizações (nesse caso), garantindo representatividade.")
# Out:
# Tamanho da Amostra Aleatória Simples: 500
# Tamanho da Amostra Estratificada: 2500
#
# Conclusão:
# Na amostragem simples, os registros são escolhidos de forma totalmente aleatória.
# Na estratificada, a escolha é proporcional às localizações (nesse caso), garantindo representatividade.
